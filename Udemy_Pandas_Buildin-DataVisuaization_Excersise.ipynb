# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df3=pd.read_csv(r'C:\Users\ss186070\OneDrive - Teradata\Documents\MyDocument\Shib\Learning\Python\Practise\udemyexercise\InputOutputData\df3')

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.shape
# Out:
# (500, 4)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 4 columns):
# a    500 non-null float64
# b    500 non-null float64
# c    500 non-null float64
# d    500 non-null float64
# dtypes: float64(4)
# memory usage: 15.8 KB

# %%
df3.describe()
# Out:
#                 a           b           c           d
# count  500.000000  500.000000  500.000000  500.000000
# mean     0.485294    0.504049    0.506183    0.517390
# std      0.290985    0.272966    0.295953    0.293166
# min      0.000410    0.010649    0.000575    0.002851
# 25%      0.225024    0.270928    0.243931    0.281738
# 50%      0.479164    0.510915    0.507474    0.533044
# 75%      0.755088    0.728839    0.769660    0.788106
# max      0.998111    0.996740    0.999709    0.989946

# %%
df3.plot.scatter(x='a',y='b',s=30,c='red',figsize=(12,3))

# %%
sns.set_style('darkgrid')
df3['a'].plot.hist()

# %%
## Set style is ggplot
plt.style.use('ggplot')
df3['a'].plot.hist(bins=20,alpha=0.5)

# %%
## Box Plot compairing a an db columns
df3[['a','b']].plot.box()

# %%
df3['d'].plot.kde()

# %%
df3['d'].plot.kde(lw=3,ls='--')

# %%
## Tabke 30 rows and create rea plot on those rows
df3.ix[0:30].plot.area(alpha=0.5)
# Out:
# C:\Users\ss186070\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated

# %%
## Legend outside the picture
f=plt.figure()
df3.ix[0:30].plot.area(alpha=0.5)
plt.legend(loc='')
