# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv(r'C:\Users\ss186070\OneDrive - Teradata\Documents\MyDocument\Shib\Learning\Python\Practise\udemyexercise\InputOutputData\df1',index_col=0)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv(r'C:\Users\ss186070\OneDrive - Teradata\Documents\MyDocument\Shib\Learning\Python\Practise\udemyexercise\InputOutputData\df2')

# %%
df2.head(10)
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008
# 5  0.286043  0.593465  0.907307  0.637898
# 6  0.430436  0.166230  0.469383  0.497701
# 7  0.312296  0.502823  0.806609  0.850519
# 8  0.187765  0.997075  0.895955  0.530390
# 9  0.908162  0.232726  0.414138  0.432007

# %%
df1['A'].hist()

# %%
sns.set_style('darkgrid')
df1['A'].hist(bins=30,color='B')

# %%
df1['A'].plot(kind='hist',color='B',bins=30)

# %%
## histogram Plot
df1['A'].plot.hist()

# %%
## Area Plot
df2.plot.area()

# %%
## Using alpha to more transparent
df2.plot.area(alpha=0.5)

# %%
## bar plot
df2.plot.bar(stacked=True)

# %%
## Line Plot
df1.plot.line(x=df1.index,y='B')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-a9ebc86a7975> in <module>
#       1 ## Line Plot
# ----> 2 df1.plot.line(x=df1.index,y='B')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#     861             >>> lines = df.plot.line(x='pig', y='horse')
#     862         """
# --> 863         return self(kind="line", x=x, y=y, **kwargs)
#     864
#     865     def bar(self, x=None, y=None, **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     757                 if is_integer(x) and not data.columns.holds_integer():
#     758                     x = data_cols[x]
# --> 759                 elif not isinstance(data[x], ABCSeries):
#     760                     raise ValueError("x must be a label or position")
# ...

# %%
df1.plot.scatter(x='A',y='B')

# %%
df1.plot.scatter(x='A',y='B',c='C')

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100)

# %%
## box Plot
df2.plot.box()

# %%
df=pd.DataFrame(np.random.rand(1000,2),columns=['a','b'])

# %%
df.head()
# Out:
#           a         b
# 0  0.029225  0.779413
# 1  0.199273  0.176853
# 2  0.906488  0.457631
# 3  0.823886  0.847229
# 4  0.074087  0.277127

# %%
df.plot.hexbin(x='a',y='b',gridsize=30)

# %%
df['a'].plot.kde()

# %%
df['a'].plot.density()

# %%
df2.plot.density()
